# %%
import json
import requests
import os
import pandas as pd
from dotenv import load_dotenv

load_dotenv(verbose=True)
# Out:
# True

# %%
API_KEY = os.getenv('SERP_API')

# %%
# データ読み込み
flavor_db = pd.read_csv('../datas/flavor_db.csv', names=['id', 'entry_id', 'alias', 'synonyms', 'scientific_name', 'category', 'molecules'], header=0)

flavor_db.drop(['id'], axis=1, inplace=True)
flavor_db["molecule_list"] = flavor_db['molecules'].apply(lambda x: x.replace("'", "").strip('{}').split(', ')).tolist()

flavor_db.tail()
# Out:
#            entry_id          alias synonyms   scientific_name        category  \
# 935 935.0       979            egg  {'Egg'}           Chicken  Animal Product
# 936 936.0       980      olive oil     {''}  Olea europaea L.        additive
# 937 NaN         981  Baking powder      NaN               NaN             NaN
# 938 NaN         982    Baking soda      NaN               NaN             NaN
# 939 NaN         983           alum      NaN               NaN             NaN
#
#                                                    molecules  \
# 935 935.0  {6274, 5311110, 644104, 9609, 18827, 527, 1960...
# 936 936.0                       {6184, 31260, 5281168, 8103}
# 937 NaN    {11265, 62465, 644104, 12297, 31242, 527, 4114...
# 938 NaN                                              {10340}
# 939 NaN                                              {24856}
#
#                                                molecule_list
# 935 935.0  [6274, 5311110, 644104, 9609, 18827, 527, 1960...
# 936 936.0                       [6184, 31260, 5281168, 8103]
# 937 NaN    [11265, 62465, 644104, 12297, 31242, 527, 4114...
# 938 NaN                                              [10340]
# 939 NaN                                              [24856]

# %%
# APIを呼び出してJSONデータを保存する関数
def fetch_and_save_json(id, query, API_KEY):
    api_url = f'https://serpapi.com/search.json?q={query}&location=Austin,Texas,United+States&hl=en&gl=us&api_key={API_KEY}'
    try:
        # APIからデータを取得
        response = requests.get(api_url)
        
        # ステータスコードが200（成功）か確認
        if response.status_code == 200:
            data = response.json()  # レスポンスをJSONとしてパース
            
            # JSONデータをファイルに保存
            with open(f'../datas/json_receipes/{id}.json', 'w') as json_file:
                json.dump(data, json_file, indent=2)  # ファイルに保存
            print(f"JSONデータが {id}.json に保存されました")
        else:
            print(f"エラーが発生しました: {response.status_code}")
    
    except requests.exceptions.RequestException as e:
        print(f"API呼び出し中にエラーが発生しました: {e}")

# %%
for index, row in flavor_db.iterrows():
    if int(index[0]) > 200:
        fetch_and_save_json(row['entry_id'], row['alias'], API_KEY)
# Out:
# JSONデータが 1.json に保存されました
# JSONデータが 2.json に保存されました
# JSONデータが 3.json に保存されました
# JSONデータが 4.json に保存されました
# JSONデータが 5.json に保存されました
# JSONデータが 6.json に保存されました
# JSONデータが 7.json に保存されました
# JSONデータが 8.json に保存されました
# JSONデータが 9.json に保存されました
# JSONデータが 10.json に保存されました
# JSONデータが 11.json に保存されました
# JSONデータが 12.json に保存されました
# JSONデータが 13.json に保存されました
# JSONデータが 14.json に保存されました
# JSONデータが 15.json に保存されました
# JSONデータが 16.json に保存されました
# JSONデータが 17.json に保存されました
# JSONデータが 18.json に保存されました
# JSONデータが 19.json に保存されました
# JSONデータが 20.json に保存されました
# JSONデータが 21.json に保存されました
# JSONデータが 22.json に保存されました
# JSONデータが 23.json に保存されました
# JSONデータが 24.json に保存されました
# JSONデータが 25.json に保存されました
# JSONデータが 26.json に保存されました
# JSONデータが 27.json に保存されました
# JSONデータが 28.json に保存されました
# JSONデータが 29.json に保存されました
# JSONデータが 30.json に保存されました
# JSONデータが 31.json に保存されました
# JSONデータが 32.json に保存されました
# JSONデータが 33.json に保存されました
# JSONデータが 34.json に保存されました
# JSONデータが 35.json に保存されました
# JSONデータが 36.json に保存されました
# JSONデータが 37.json に保存されました
# JSONデータが 38.json に保存されました
# JSONデータが 39.json に保存されました
# JSONデータが 40.json に保存されました
# JSONデータが 41.json に保存されました
# JSONデータが 42.json に保存されました
# JSONデータが 43.json に保存されました
# JSONデータが 44.json に保存されました
# JSONデータが 45.json に保存されました
# JSONデータが 46.json に保存されました
# JSONデータが 47.json に保存されました
# JSONデータが 48.json に保存されました
# JSONデータが 49.json に保存されました
# JSONデータが 50.json に保存されました
# JSONデータが 51.json に保存されました
# JSONデータが 52.json に保存されました
# JSONデータが 53.json に保存されました
# JSONデータが 54.json に保存されました
# JSONデータが 55.json に保存されました
# JSONデータが 56.json に保存されました
# JSONデータが 57.json に保存されました
# JSONデータが 58.json に保存されました
# JSONデータが 59.json に保存されました
# JSONデータが 60.json に保存されました
# JSONデータが 61.json に保存されました
# JSONデータが 62.json に保存されました
# JSONデータが 63.json に保存されました
# JSONデータが 64.json に保存されました
# JSONデータが 65.json に保存されました
# JSONデータが 66.json に保存されました
# JSONデータが 67.json に保存されました
# JSONデータが 68.json に保存されました
# JSONデータが 69.json に保存されました
# JSONデータが 70.json に保存されました
# JSONデータが 71.json に保存されました
# JSONデータが 72.json に保存されました
# JSONデータが 73.json に保存されました
# JSONデータが 74.json に保存されました
# JSONデータが 75.json に保存されました
# JSONデータが 76.json に保存されました
# JSONデータが 77.json に保存されました
# JSONデータが 78.json に保存されました
# JSONデータが 79.json に保存されました
# JSONデータが 80.json に保存されました
# JSONデータが 81.json に保存されました
# JSONデータが 82.json に保存されました
# JSONデータが 83.json に保存されました
# JSONデータが 84.json に保存されました
# JSONデータが 85.json に保存されました
# JSONデータが 86.json に保存されました
# JSONデータが 87.json に保存されました
# JSONデータが 88.json に保存されました
# JSONデータが 89.json に保存されました
# JSONデータが 90.json に保存されました
# JSONデータが 91.json に保存されました
# JSONデータが 92.json に保存されました
# JSONデータが 93.json に保存されました
# JSONデータが 94.json に保存されました
# JSONデータが 95.json に保存されました
# JSONデータが 96.json に保存されました
# JSONデータが 97.json に保存されました
# JSONデータが 98.json に保存されました
# JSONデータが 99.json に保存されました
# JSONデータが 100.json に保存されました
# JSONデータが 101.json に保存されました
# JSONデータが 102.json に保存されました
# JSONデータが 103.json に保存されました
# JSONデータが 104.json に保存されました
# JSONデータが 105.json に保存されました
# JSONデータが 106.json に保存されました
# JSONデータが 107.json に保存されました
# JSONデータが 108.json に保存されました
# JSONデータが 109.json に保存されました
# JSONデータが 110.json に保存されました
# JSONデータが 111.json に保存されました
# JSONデータが 112.json に保存されました
# JSONデータが 113.json に保存されました
# JSONデータが 114.json に保存されました
# JSONデータが 115.json に保存されました
# JSONデータが 116.json に保存されました
# JSONデータが 117.json に保存されました
# JSONデータが 118.json に保存されました
# JSONデータが 119.json に保存されました
# JSONデータが 120.json に保存されました
# JSONデータが 121.json に保存されました
# JSONデータが 122.json に保存されました
# JSONデータが 123.json に保存されました
# JSONデータが 124.json に保存されました
# JSONデータが 125.json に保存されました
# JSONデータが 126.json に保存されました
# JSONデータが 127.json に保存されました
# JSONデータが 128.json に保存されました
# JSONデータが 129.json に保存されました
# JSONデータが 130.json に保存されました
# JSONデータが 131.json に保存されました
# JSONデータが 132.json に保存されました
# JSONデータが 133.json に保存されました
# JSONデータが 134.json に保存されました
# JSONデータが 135.json に保存されました
# JSONデータが 136.json に保存されました
# JSONデータが 137.json に保存されました
# JSONデータが 138.json に保存されました
# JSONデータが 139.json に保存されました
# JSONデータが 140.json に保存されました
# JSONデータが 141.json に保存されました
# JSONデータが 142.json に保存されました
# JSONデータが 143.json に保存されました
# JSONデータが 144.json に保存されました
# JSONデータが 145.json に保存されました
# JSONデータが 146.json に保存されました
# JSONデータが 147.json に保存されました
# JSONデータが 148.json に保存されました
# JSONデータが 149.json に保存されました
# JSONデータが 150.json に保存されました
# JSONデータが 151.json に保存されました
# JSONデータが 152.json に保存されました
# JSONデータが 153.json に保存されました
# JSONデータが 154.json に保存されました
# JSONデータが 155.json に保存されました
# JSONデータが 156.json に保存されました
# JSONデータが 157.json に保存されました
# JSONデータが 158.json に保存されました
# JSONデータが 159.json に保存されました
# JSONデータが 160.json に保存されました
# JSONデータが 161.json に保存されました
# JSONデータが 162.json に保存されました
# JSONデータが 163.json に保存されました
# JSONデータが 164.json に保存されました
# JSONデータが 165.json に保存されました
# JSONデータが 166.json に保存されました
# JSONデータが 167.json に保存されました
# JSONデータが 168.json に保存されました
# JSONデータが 169.json に保存されました
# JSONデータが 170.json に保存されました
# JSONデータが 171.json に保存されました
# JSONデータが 172.json に保存されました
# JSONデータが 173.json に保存されました
# JSONデータが 174.json に保存されました
# JSONデータが 175.json に保存されました
# JSONデータが 176.json に保存されました
# JSONデータが 177.json に保存されました
# JSONデータが 178.json に保存されました
# JSONデータが 179.json に保存されました
# JSONデータが 180.json に保存されました
# JSONデータが 181.json に保存されました
# JSONデータが 182.json に保存されました
# JSONデータが 183.json に保存されました
# JSONデータが 184.json に保存されました
# JSONデータが 185.json に保存されました
# JSONデータが 186.json に保存されました
# JSONデータが 187.json に保存されました
# JSONデータが 188.json に保存されました
# JSONデータが 189.json に保存されました
# JSONデータが 190.json に保存されました
# JSONデータが 191.json に保存されました
# JSONデータが 192.json に保存されました
# JSONデータが 193.json に保存されました
# JSONデータが 194.json に保存されました
# JSONデータが 195.json に保存されました
# JSONデータが 196.json に保存されました
# JSONデータが 197.json に保存されました
# JSONデータが 198.json に保存されました
# JSONデータが 199.json に保存されました
# JSONデータが 200.json に保存されました
# JSONデータが 201.json に保存されました
# JSONデータが 202.json に保存されました
# JSONデータが 203.json に保存されました
# JSONデータが 204.json に保存されました
# JSONデータが 205.json に保存されました
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 3
#       1 for index, row in flavor_db.iterrows():
#       2     # if int(index[0]) > 2:
# ----> 3         fetch_and_save_json(row['entry_id'], row['alias'], API_KEY)
#
# Cell In[30], line 6, in fetch_and_save_json(id, query, API_KEY)
#       3 api_url = f'https://serpapi.com/search.json?q={query}&location=Austin,Texas,United+States&hl=en&gl=us&api_key={API_KEY}'
#       4 try:
#       5     # APIからデータを取得
# ----> 6     response = requests.get(api_url)
#       8     # ステータスコードが200（成功）か確認
#       9     if response.status_code == 200:
#
# File ~/.pyenv/versions/3.10.0/envs/recipe-qa-3.10/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/.pyenv/versions/3.10.0/envs/recipe-qa-3.10/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.pyenv/versions/3.10.0/envs/recipe-qa-3.10/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.pyenv/versions/3.10.0/envs/recipe-qa-3.10/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/3.10.0/envs/recipe-qa-3.10/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/.pyenv/versions/3.10.0/envs/recipe-qa-3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/.pyenv/versions/3.10.0/envs/recipe-qa-3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/.pyenv/versions/3.10.0/envs/recipe-qa-3.10/lib/python3.10/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/http/client.py:1368, in HTTPConnection.getresponse(self)
#    1366 try:
#    1367     try:
# -> 1368         response.begin()
#    1369     except ConnectionError:
#    1370         self.close()
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/http/client.py:317, in HTTPResponse.begin(self)
#     315 # read until we get a non-100 response
#     316 while True:
# --> 317     version, status, reason = self._read_status()
#     318     if status != CONTINUE:
#     319         break
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/http/client.py:278, in HTTPResponse._read_status(self)
#     277 def _read_status(self):
# --> 278     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     279     if len(line) > _MAXLINE:
#     280         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1269     if flags != 0:
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#    1275     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1127 try:
#    1128     if buffer is not None:
# -> 1129         return self._sslobj.read(len, buffer)
#    1130     else:
#    1131         return self._sslobj.read(len)
#
# KeyboardInterrupt:
